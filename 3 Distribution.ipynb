# %%
import random
import matplotlib.pyplot as plt
from matplotlib.cm import ScalarMappable
from matplotlib.colors import LinearSegmentedColormap, Normalize
import igraph as ig

import networkx as nx
import pandas as pd
import numpy as np
import os
import math
import re
from collections import Counter
import scipy.stats
import seaborn as sns
from matplotlib.font_manager import FontProperties  # 导入FontProperties
import warnings
warnings.filterwarnings("ignore")

# %%
fallhit = pd.read_csv(r'E:\netData\MAG-all\paper & hit.zip')

# %%
fLauCounter = pd.read_csv(r"E:\netData\MAG-nobel\2 Nobel laureates counterparts\counterparts.zip")

# %%
fLau = pd.read_csv(r"E:\netData\MAG-nobel\361 Nobel laureates.csv")

# %%
sns.set_theme(style="ticks")
f, ax = plt.subplots(figsize=(10, 6))

g = sns.lineplot(
    data=fallhit[fallhit['paperyear']>1850],x="paperyear", y=r'cit'
)

ax.yaxis.grid(True)

g.set_xticks([1870,1900,1930,1960,1990,2020])

plt.xticks(size = 25)
plt.yticks(size = 25)
plt.ylabel(r'citation',fontsize = 25)

ax.set(xlabel="")
sns.despine(trim=True, left=True)
plt.savefig(r"F:\A J YANG PAPER\Nobel analysis\STI apex index\figs\fig 3\3.pdf",bbox_inches = 'tight')

# %%
sns.set_theme(style="ticks")
f, ax = plt.subplots(figsize=(10, 6))

g = sns.lineplot(
    data=fallhit[fallhit['paperyear']>1850],x="paperyear", y=r'hitcitnum'
)

ax.yaxis.grid(True)

g.set_xticks([1870,1900,1930,1960,1990,2020])

plt.xticks(size = 25)
plt.yticks(size = 25)
plt.ylabel(r'citation',fontsize = 25)

ax.set(xlabel="")
sns.despine(trim=True, left=True)
plt.savefig(r"F:\A J YANG PAPER\Nobel analysis\STI apex index\figs\fig 3\4.pdf",bbox_inches = 'tight')
